# %% [markdown]
# # E-commerse Product Categorization

# %% [markdown]
# # Problem Statement
#
# in the era of e-commerce and retail, the biggest challenge is to tag a particulary product to it's category. There are billions of items, and manually tagging is an inefficient task and cost to a company. It must be done intelligently and fast. New items are added to the website or store every day and detectign the category is critical. Machine learning and natural language processing come to the rescue to solve this problem and save a lot of time and money.

# %% [markdown]
# In this project, i build a predictive model and categorize products in an e-commerse data set. Product categorization is a supervised classification problem where the product categories are the target classes, and the features are the words extracted from the product description or an image

# %% [markdown]
# The aim is to successfully classify product categories with high precision using state of the art machine learning and deep elarning techniques.

# %% [markdown]
# # Imports

# %%
# Data manipulation
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.layers import (
    Input,
    Dense,
    Dropout,
    Embedding,
    LSTM,
    Flatten,
    Conv1D,
    MaxPooling1D,
)
from tensorflow.keras.models import Model
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras import layers


import nltk
from nltk.corpus import stopwords
from wordcloud import WordCloud, STOPWORDS

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

from imblearn.over_sampling import SMOTE
# Out:
# 2024-10-05 20:40:06.660772: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-10-05 20:40:06.672859: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-10-05 20:40:06.687144: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-10-05 20:40:06.691232: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-10-05 20:40:06.703141: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-10-05 20:40:07.306652: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# # Exploratory data Analysis </br> the data has 20,000 rows and 15 columns
#
# The dataset provides comprehensive product details from Flipkart, one of India's leading e-commerce platforms, for the year 2017. it offers valuable insights into the e-commerce landscape of the time, capturing a wide array of product information access various categories </br>
#
# sample source: https://data.world/promptcloud/product-details-on-flipkart-com </br>
# original dataset: https://app.datastock.shop/?site%5C_name=Flipkart%5C_Product%5C_Listings
# </br>
# the data set description:</br>
# Key Features:
# Product Information: Detailed descriptions, specifications, and features for thousands of products.
# Pricing Data: Includes original prices, discounts, and final sale prices to understand pricing strategies.
# Category Coverage: A wide range of product categories, including electronics, fashion, home appliances, books, and more.
# Customer Reviews and Ratings: Aggregated customer feedback to assess product popularity and customer satisfaction.
# Seller Information: Data about various sellers, providing insights into market competition and seller performance.

# %%
# %matplotlib inline

# Loading the data
prod_cat_data = pd.read_csv('ecommerce.csv')
prod_cat_data.head()
# Out:
#                             uniq_id            crawl_timestamp  \
# 0  c2d766ca982eca8304150849735ffef9  2016-03-25 22:59:23 +0000
# 1  7f7036a6d550aaa89d34c77bd39a5e48  2016-03-25 22:59:23 +0000
# 2  f449ec65dcbc041b6ae5e6a32717d01b  2016-03-25 22:59:23 +0000
# 3  0973b37acd0c664e3de26e97e5571454  2016-03-25 22:59:23 +0000
# 4  bc940ea42ee6bef5ac7cea3fb5cfbee7  2016-03-25 22:59:23 +0000
#
#                                          product_url  \
# 0  http://www.flipkart.com/alisha-solid-women-s-c...
# 1  http://www.flipkart.com/fabhomedecor-fabric-do...
# 2  http://www.flipkart.com/aw-bellies/p/itmeh4grg...
# 3  http://www.flipkart.com/alisha-solid-women-s-c...
# 4  http://www.flipkart.com/sicons-all-purpose-arn...
#
#                             product_name  \
# 0    Alisha Solid Women's Cycling Shorts
# 1    FabHomeDecor Fabric Double Sofa Bed
# 2                             AW Bellies
# 3    Alisha Solid Women's Cycling Shorts
# 4  Sicons All Purpose Arnica Dog Shampoo
#
#                                product_category_tree               pid  \
# 0  ["Clothing >> Women's Clothing >> Lingerie, Sl...  SRTEH2FF9KEDEFGF
# 1  ["Furniture >> Living Room Furniture >> Sofa B...  SBEEH3QGU7MFYJFY
# 2  ["Footwear >> Women's Footwear >> Ballerinas >...  SHOEH4GRSUBJGZXE
# 3  ["Clothing >> Women's Clothing >> Lingerie, Sl...  SRTEH2F6HUZMQ6SJ
# 4  ["Pet Supplies >> Grooming >> Skin & Coat Care...  PSOEH3ZYDMSYARJ5
#
#    retail_price  discounted_price  \
# 0         999.0             379.0
# 1       32157.0           22646.0
# 2         999.0             499.0
# 3         699.0             267.0
# 4         220.0             210.0
#
#                                                image  is_FK_Advantage_product  \
# 0  ["http://img5a.flixcart.com/image/short/u/4/a/...                    False
# 1  ["http://img6a.flixcart.com/image/sofa-bed/j/f...                    False
# 2  ["http://img5a.flixcart.com/image/shoe/7/z/z/r...                    False
# 3  ["http://img5a.flixcart.com/image/short/6/2/h/...                    False
# 4  ["http://img5a.flixcart.com/image/pet-shampoo/...                    False
#
#                                          description       product_rating  \
# 0  Key Features of Alisha Solid Women's Cycling S...  No rating available
# 1  FabHomeDecor Fabric Double Sofa Bed (Finish Co...  No rating available
# 2  Key Features of AW Bellies Sandals Wedges Heel...  No rating available
# 3  Key Features of Alisha Solid Women's Cycling S...  No rating available
# 4  Specifications of Sicons All Purpose Arnica Do...  No rating available
#
#         overall_rating         brand  \
# 0  No rating available        Alisha
# 1  No rating available  FabHomeDecor
# 2  No rating available            AW
# 3  No rating available        Alisha
# 4  No rating available        Sicons
#
#                               product_specifications
# 0  {"product_specification"=>[{"key"=>"Number of ...
# 1  {"product_specification"=>[{"key"=>"Installati...
# 2  {"product_specification"=>[{"key"=>"Ideal For"...
# 3  {"product_specification"=>[{"key"=>"Number of ...
# 4  {"product_specification"=>[{"key"=>"Pet Type",...

# %%
prod_cat_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   uniq_id                  20000 non-null  object
#  1   crawl_timestamp          20000 non-null  object
#  2   product_url              20000 non-null  object
#  3   product_name             20000 non-null  object
#  4   product_category_tree    20000 non-null  object
#  5   pid                      20000 non-null  object
#  6   retail_price             19922 non-null  float64
#  7   discounted_price         19922 non-null  float64
#  8   image                    19997 non-null  object
#  9   is_FK_Advantage_product  20000 non-null  bool
#  10  description              19998 non-null  object
#  11  product_rating           20000 non-null  object
#  12  overall_rating           20000 non-null  object
#  13  brand                    14136 non-null  object
#  14  product_specifications   19986 non-null  object
# dtypes: bool(1), float64(2), object(12)
# memory usage: 2.2+ MB

# %% [markdown]
# The e-commerce data set has 15 attributes; out of these columns, i will only extract the following for further analysis: description and product_category_tree.
# The remaining columns are not important for the text classification model.

# %%
prod_cat_data["product_category_tree"].value_counts()
# Out:
# product_category_tree
# ["Jewellery >> Necklaces & Chains >> Necklaces"]                                                                                                                1567
# ["Jewellery >> Rings"]                                                                                                                                           710
# ["Automotive >> Accessories & Spare parts >> Car Interior & Exterior >> Car Interior >> Car Mats"]                                                               522
# ["Jewellery >> Bangles, Bracelets & Armlets >> Bangles"]                                                                                                         430
# ["Tools & Hardware >> Tools >> Gardening Tools >> Plant Containers & Sets >> Plant Container Sets"]                                                              332
#                                                                                                                                                                 ...
# ["Clothing >> Kids' Clothing >> Infants Wear >> Baby Boys >> Accessories >> Socks >> Ole Baby Socks >> Ole Baby Baby Boy's, Baby Girl's Woven Ankle Len..."]       1
# ["Clothing >> Women's Clothing >> Lingerie, Sleep & Swimwear >> Babydolls >> Heart 2 Heart Babydolls >> Heart 2 Heart Printed Babydoll"]                           1
# ["Clothing >> Women's Clothing >> Western Wear >> Dresses & Skirts >> Skirts >> Indigocart Skirts >> Indigocart Printed Women's Regular Skirt"]                    1
# ["Clothing >> Men's Clothing >> Shirts >> Formal Shirts >> Hoffmen Formal Shirts >> Hoffmen Men's Self Design Formal Shirt"]                                       1
# ["Baby Care >> Baby & Kids Gifts >> Stickers >> Fun To See Stickers"]                                                                                              1
# Name: count, Length: 6466, dtype: int64

# %% [markdown]
# #### Plotting the product category distribution to visualize and understand better

# %%
# fig, ax = plt.subplots(figsize=[8, 4], nrows=1, ncols=1)
# prod_cat_data["product_category_tree"].value_counts().plot(
#     ax=ax, kind="bar", title="Product Category Distribution"
# )
# plt.show()


# Plotting the product category distribution
# Extract top 10 categories
top_10_categories = prod_cat_data["product_category_tree"].value_counts().nlargest(10)

# Plotting the top 10 categories
fig, ax = plt.subplots(figsize=(10, 6))  # Set the figure size
top_10_categories.plot(
    ax=ax,
    kind="bar",
    color=sns.color_palette("tab10"),
    title="Top 10 Product Categories Distribution",
)
plt.xlabel("Product Categories")
plt.ylabel("Number of Products")
plt.xticks(rotation=45, ha="right")  # Rotate category labels for better readability
plt.tight_layout()  # Adjust layout for better fit
plt.show()
# Out:
# /tmp/ipykernel_17997/3460730759.py:23: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()  # Adjust layout for better fit

# %% [markdown]
# ## Data Preprocessing

# %%
# Checking for missing values in each column
missing = pd.DataFrame(prod_cat_data.isnull().sum()).rename(columns={0: "missing"})

# Creating percentage of missing values
missing["percent"] = missing["missing"] / len(prod_cat_data)

# sort teh values in descending order to see highest count on the top
missing.sort_values("percent", ascending=False)
# Out:
#                          missing  percent
# brand                       5864  0.29320
# retail_price                  78  0.00390
# discounted_price              78  0.00390
# product_specifications        14  0.00070
# image                          3  0.00015
# description                    2  0.00010
# uniq_id                        0  0.00000
# crawl_timestamp                0  0.00000
# product_url                    0  0.00000
# product_name                   0  0.00000
# product_category_tree          0  0.00000
# pid                            0  0.00000
# is_FK_Advantage_product        0  0.00000
# product_rating                 0  0.00000
# overall_rating                 0  0.00000

# %% [markdown]
# # We can see there are some missing values in the data set

# %%
# Removing missing values in description

prod_cat_data = prod_cat_data[pd.notnull(prod_cat_data["description"])]

# %%
# Add new column with number of words in the description before preprocessing

prod_cat_data["no_of_words"] = prod_cat_data.description.apply(lambda a: len(a.split()))
bins = [0, 50, 75, np.inf]
prod_cat_data["bins"] = pd.cut(
    prod_cat_data.no_of_words,
    bins=[0, 100, 300, 500, 800, np.inf],
    labels=["0-100", "100-200", "200-500", "500-800", ">800"],
)

words_distribution = (
    prod_cat_data.groupby("bins")
    .size()
    .reset_index()
    .rename(columns={0: "word_counts"})
)
sns.barplot(x="bins", y="word_counts", data=words_distribution).set_title(
    "Word distribution per bin"
)
# Out:
# /tmp/ipykernel_17997/1032067432.py:12: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   prod_cat_data.groupby("bins")
# Text(0.5, 1.0, 'Word distribution per bin')

# %% [markdown]
# #### Most of the descriptions have fewer than 200 words. And more than 80% contains fewer than 100 words

# %% [markdown]
# # Text preprocessing

# %%
# example description
prod_cat_data["description"][1]
# Out:
# "FabHomeDecor Fabric Double Sofa Bed (Finish Color - Leatherette Black Mechanism Type - Pull Out) Price: Rs. 22,646 • Fine deep seating experience • Save Space with the all new click clack Sofa Bed • Easy to fold and vice versa with simple click clack mechanism • Chrome legs with mango wood frame for long term durability • Double cushioned Sofa Bed to provide you with extra softness to make a fine seating experience • A double bed that can easily sleep two,Specifications of FabHomeDecor Fabric Double Sofa Bed (Finish Color - Leatherette Black Mechanism Type - Pull Out) Installation & Demo Installation & Demo Details Installation and demo for this product is done free of cost as part of this purchase. Our service partner will visit your location within 72 business hours from the delivery of the product. In The Box 1 Sofa Bed General Brand FabHomeDecor Mattress Included No Delivery Condition Knock Down Storage Included No Mechanism Type Pull Out Type Sofa Bed Style Contemporary & Modern Filling Material Microfiber Seating Capacity 3 Seater Upholstery Type NA Upholstery Included No Bed Size Double Shape Square Suitable For Living Room Model Number FHD112 Care Instructions Avoid outdoor use and exposure to water or prolonged moisture, Avoid exposure to direct heat or sunlight as this can cause the sofa colour to fade, Keep sharp objects away from your sofa, A little tear on the fabric cover may be hard to repair, Vacuum your sofas periodically with a soft bristled bru...View More Avoid outdoor use and exposure to water or prolonged moisture, Avoid exposure to direct heat or sunlight as this can cause the sofa colour to fade, Keep sharp objects away from your sofa, A little tear on the fabric cover may be hard to repair, Vacuum your sofas periodically with a soft bristled brush attachment or lightly brush them to keep general dirt and dust off the sofa and prevent any embedding between the fibres, Try to avoid food and drink spillage of any kind, If spills occur, do not leave unattended, In case of a stain, a water-free fabric cleaner can be used, However, avoid applying the cleaner directly on the stain as this can cause damage to the fabric and fade colour, Pour the cleaner onto a clean cloth and test its effect on a hidden area of the sofa before cleaning the stain with the cloth, A professional scotchguard treatment is one of the easiest and most effective options to protect against spills or stains and keep pet hair at bay, Getting your sofa professionally cleaned once every 6-8 months will not only take care of the nooks and corners that you can't reach, it will also make it more durable Finish Type Matte Important Note Cancellation NOT allowed for this product after 24 hrs of order booking. Warranty Covered in Warranty Warranty covers all kind of manufacturing defects. Concerned product will either be repaired or replaced based on discretion. Service Type Manufacturer Warranty Warranty Summary 6 Months Domestic Warranty Not Covered in Warranty Warranty does not cover for Improper Handling Dimensions Weight 40 kg Height 838 mm Width 1905 mm Depth 939 mm Disclaimer - The color of the product may vary slightly compared to the picture displayed on your screen. This is due to lighting, pixel quality and color settings - Please check the product's dimensions to ensure the product will fit in the desired location. Also, check if the product will fit through...View More - The color of the product may vary slightly compared to the picture displayed on your screen. This is due to lighting, pixel quality and color settings - Please check the product's dimensions to ensure the product will fit in the desired location. Also, check if the product will fit through the entrance(s) and door(s) of the premises - Please expect an unevenness of up to 5 mm in the product due to differences in surfaces and floor levels - Flipkart, or the Seller delivering the product, will not take up any type of civil work, such as drilling holes in the wall to  ...

# %%
import tensorflow as tf

# example description
prod_cat_data["description"][2]

# Remove punctuation
prod_cat_data["description"] = tf.strings.regex_replace(
    prod_cat_data["description"], "[^\\w\\d\\s]", " "
)

# # Replace whitespace between terms with a single space
prod_cat_data["description"] = tf.strings.regex_replace(
    prod_cat_data["description"], "\\s+", " "
)

# Remove leading and trailing whitespace
prod_cat_data["description"] = tf.strings.strip(prod_cat_data["description"])

# converting to lower case
prod_cat_data["description"] = tf.strings.lower(prod_cat_data["description"])
# Prod_cat_data["description"] = Prod_cat_data["description"].str.lower()

# Replace numbers like price values with 'numbr'
prod_cat_data["description"] = tf.strings.regex_replace(
    prod_cat_data["description"], "\\d+(\\.\\d+)?", "numbr"
)

# example text
prod_cat_data["description"][1]
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1728175208.899420   17997 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1728175208.926642   17997 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1728175208.926707   17997 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1728175208.929491   17997 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1728175208.929555   17997 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1728175208.929573   17997 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1728175209.064550   17997 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1728175209.064634   17997 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-10-05 20:40:09.064645: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2112] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# I0000 00:00:1728175209.064689   17997 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-10-05 20:40:09.064710: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5520 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4070 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.9
# b'fabhomedecor fabric double sofa bed finish color leatherette black mechanism type pull out price rs numbr numbr fine deep seating experience save space with the all new click clack sofa bed easy to fold and vice versa with simple click clack mechanism chrome legs with mango wood frame for long term durability double cushioned sofa bed to provide you with extra softness to make a fine seating experience a double bed that can easily sleep two specifications of fabhomedecor fabric double sofa bed finish color leatherette black mechanism type pull out installation demo installation demo details installation and demo for this product is done free of cost as part of this purchase our service partner will visit your location within numbr business hours from the delivery of the product in the box numbr sofa bed general brand fabhomedecor mattress included no delivery condition knock down storage included no mechanism type pull out type sofa bed style contemporary modern filling material microfiber seating capacity numbr seater upholstery type na upholstery included no bed size double shape square suitable for living room model number fhdnumbr care instructions avoid outdoor use and exposure to water or prolonged moisture avoid exposure to direct heat or sunlight as this can cause the sofa colour to fade keep sharp objects away from your sofa a little tear on the fabric cover may be hard to repair vacuum your sofas periodically with a soft bristled bru view more avoid outdoor use and exposure to water or prolonged moisture avoid exposure to direct heat or sunlight as this can cause the sofa colour to fade keep sharp objects away from your sofa a little tear on the fabric cover may be hard to repair vacuum your sofas periodically with a soft bristled brush attachment or lightly brush them to keep general dirt and dust off the sofa and prevent any embedding between the fibres try to avoid food and drink spillage of any kind if spills occur do not leave unattended in case of a stain a water free fabric cleaner can be used however avoid applying the cleaner directly on the stain as this can cause damage to the fabric and fade colour pour the cleaner onto a clean cloth and test its effect on a hidden area of the sofa before cleaning the stain with the cloth a professional scotchguard treatment is one of the easiest and most effective options to protect against spills or stains and keep pet hair at bay getting your sofa professionally cleaned once every numbr numbr months will not only take care of the nooks and corners that you can t reach it will also make it more durable finish type matte important note cancellation not allowed for this product after numbr hrs of order booking warranty covered in warranty warranty covers all kind of manufacturing defects concerned product will either be repaired or replaced based on discretion service type manufacturer warranty warranty summary numbr months domestic warranty not covered in warranty warranty does not cover for improper handling dimensions weight numbr kg height numbr mm width numbr mm depth numbr mm disclaimer the color of the product may vary slightly compared to the picture displayed on your screen this is due to lighting pixel quality and color settings please check the product s dimensions to ensure the product will fit in the desired location also check if the product will fit through view more the color of the product may vary slightly compared to the picture displayed on your screen this is due to lighting pixel quality and color settings please check the product s dimensions to ensure the product will fit in the desired location also check if the product will fit through the entrance s and door s of the premises please expect an unevenness of up to numbr mm in the product due to differences in surfaces and floor levels flipkart or the seller delivering the product will not take up any type of civil work such as drilling holes in the wall to mount the product the product will only ...

# %% [markdown]
# ### the original category had sub categories which i will not worry about for now. with a bit of text processing, i will only select the main categories as the labels

# %%
print(prod_cat_data["product_category_tree"][1])

prod_cat_data["product_category_tree"] = tf.strings.regex_replace(
    prod_cat_data["product_category_tree"], "[^\\w\\d\\s]", " "
)

prod_cat_data["product_category_tree"] = tf.strings.strip(
    prod_cat_data["product_category_tree"], " "
)

prod_cat_data["product_category_tree"] = prod_cat_data["product_category_tree"].apply(
    lambda x: x.decode("utf-8")
)

prod_cat_data["product_category_tree"] = prod_cat_data["product_category_tree"].apply(
    lambda x: x.split(" ")[0]
)

prod_cat_data["product_category_tree"]
# Out:
# ["Furniture >> Living Room Furniture >> Sofa Beds & Futons >> FabHomeDecor Fabric Double Sofa Bed (Finish Colo..."]
# 0         Clothing
# 1        Furniture
# 2         Footwear
# 3         Clothing
# 4              Pet
#            ...
# 19995         Baby
# 19996         Baby
# 19997         Baby
# 19998         Baby
# 19999         Baby
# Name: product_category_tree, Length: 19998, dtype: object

# %% [markdown]
# import stop words from NLTK and remove from the description.

# %%
nltk.download("stopwords")
stop = stopwords.words("english")
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/mbeleck/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
pattern = r"\b(?:{})\b".format("|".join(stop))

prod_cat_data["description"] = tf.strings.regex_replace(
    prod_cat_data["description"], pattern, ""
)

prod_cat_data["description"] = tf.strings.regex_replace(
    prod_cat_data["description"], "\\s+", " "
)  # Removing single characters


# prod_cat_data["description"] = prod_cat_data["description"].apply(
#     lambda a: " ".join(a for a in a.split() if len(a) > 1)
# )

prod_cat_data["description"][1]
# Out:
# b'fabhomedecor fabric double sofa bed finish color leatherette black mechanism type pull price rs numbr numbr fine deep seating experience save space new click clack sofa bed easy fold vice versa simple click clack mechanism chrome legs mango wood frame long term durability double cushioned sofa bed provide extra softness make fine seating experience double bed easily sleep two specifications fabhomedecor fabric double sofa bed finish color leatherette black mechanism type pull installation demo installation demo details installation demo product done free cost part purchase service partner visit location within numbr business hours delivery product box numbr sofa bed general brand fabhomedecor mattress included delivery condition knock storage included mechanism type pull type sofa bed style contemporary modern filling material microfiber seating capacity numbr seater upholstery type na upholstery included bed size double shape square suitable living room model number fhdnumbr care instructions avoid outdoor use exposure water prolonged moisture avoid exposure direct heat sunlight cause sofa colour fade keep sharp objects away sofa little tear fabric cover may hard repair vacuum sofas periodically soft bristled bru view avoid outdoor use exposure water prolonged moisture avoid exposure direct heat sunlight cause sofa colour fade keep sharp objects away sofa little tear fabric cover may hard repair vacuum sofas periodically soft bristled brush attachment lightly brush keep general dirt dust sofa prevent embedding fibres try avoid food drink spillage kind spills occur leave unattended case stain water free fabric cleaner used however avoid applying cleaner directly stain cause damage fabric fade colour pour cleaner onto clean cloth test effect hidden area sofa cleaning stain cloth professional scotchguard treatment one easiest effective options protect spills stains keep pet hair bay getting sofa professionally cleaned every numbr numbr months take care nooks corners reach also make durable finish type matte important note cancellation allowed product numbr hrs order booking warranty covered warranty warranty covers kind manufacturing defects concerned product either repaired replaced based discretion service type manufacturer warranty warranty summary numbr months domestic warranty covered warranty warranty cover improper handling dimensions weight numbr kg height numbr mm width numbr mm depth numbr mm disclaimer color product may vary slightly compared picture displayed screen due lighting pixel quality color settings please check product dimensions ensure product fit desired location also check product fit view color product may vary slightly compared picture displayed screen due lighting pixel quality color settings please check product dimensions ensure product fit desired location also check product fit entrance door premises please expect unevenness numbr mm product due differences surfaces floor levels flipkart seller delivering product take type civil work drilling holes wall mount product product assembled case carpentry assembly required case product appears lack shine wiping surface cloth help clear surface dust particles material color upholstery color leatherette black primary color black primary material fabric secondary material subtype mango wood secondary material foam finish color leatherette black primary material subtype foam'

# %%
len(prod_cat_data["product_category_tree"].unique())
# Out:
# 202

# %%
top_10_categories = prod_cat_data["product_category_tree"].value_counts().nlargest(10)

# Plotting the top 10 categories
fig, ax = plt.subplots(figsize=(10, 6))  # Set the figure size
top_10_categories.plot(
    ax=ax,
    kind="bar",
    color=sns.color_palette("tab10"),
    title="Top 10 Product Categories Distribution",
)
plt.xlabel("Product Categories")  # X-axis label
plt.ylabel("Number of Products")  # Y-axis label
plt.xticks(rotation=45, ha="right")  # Rotate category labels for better readability
plt.tight_layout()  # Adjust layout for better fit
plt.show()

# %% [markdown]
# ### plotting word cloud to visualize the most frequent words

# %%
# word cloud
# convert tensorflow strings back to numpy
prod_cat_data["description"] = prod_cat_data["description"].apply(
    lambda x: x.decode("utf-8")
)


wordcloud = WordCloud(background_color="white", width=800, height=400).generate(
    " ".join(prod_cat_data["description"])
)
plt.figure(figsize=(15, 8))
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %% [markdown]
# from the wordcloud there are words like number, com, free, day, etc
# these are domain specific words i don't need for my task. so i will remove them
# we also don't need the numbers which i replaced with 'numbr'

# %%
specific_stop_words = [
    "numbr",
    "rs",
    "flipkart",
    "buy",
    "com",
    "free",
    "day",
    "cash",
    "replacement",
    "guarantee",
    "genuine",
    "key",
    "feature",
    "delivery",
    "products",
    "product",
    "shipping",
    "online",
    "india",
    "shop",
]

prod_cat_data["description"] = prod_cat_data["description"].apply(
    lambda a: " ".join(a for a in a.split() if a not in specific_stop_words)
)

# %% [markdown]
# ### new word could

# %%
wordcloud = WordCloud(background_color="white", width=800, height=400).generate(
    " ".join(prod_cat_data["description"])
)
plt.figure(figsize=(15, 8))
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %% [markdown]
# ## Feature engineering

# %% [markdown]
# i convert the text data into features. i will only consider 200 features since the most of the descriptions were below 200 characters long

# %%
MAX_LENGTH = 200
prod_tok = Tokenizer()
prod_tok.fit_on_sequences(prod_cat_data["description"])
clean_description = prod_tok.texts_to_sequences(prod_cat_data["description"])

# padding
X = pad_sequences(clean_description, maxlen=MAX_LENGTH)


# label encoder for Target variables
from sklearn.preprocessing import LabelEncoder

num_classes = len(np.unique(prod_cat_data.product_category_tree.values))
y = prod_cat_data["product_category_tree"].values
encoder = LabelEncoder()
encoder.fit(y)
y = encoder.transform(y)

len(X), len(y)
# Out:
# (19998, 19998)

# %% [markdown]
# ## Train-Test split

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (15998, 200)
# (15998,)
# (4000, 200)
# (4000,)

# %% [markdown]
# # Model Building

# %% [markdown]
# ## Model 1 - ANN
#
# #### Architecture: The input neurons are max_length.
#
# 1. Embedding or hidden layer with a linear activation function,
# 2. Softmax layer with 6466 neurons since there are 202 unique classes
# 3. rmsprop optimizer with categorical cross-entropy as a loss function

# %%
VOCAB_SIZE = 10000

# vectorize_layer = TextVectorization(
#     max_tokens=VOCAB_SIZE, output_mode="int", output_sequence_length=MAX_LENGTH
# )

# train_text = train_ds.map(lambda text, labels: text)
# vectorize_layer.adapt(train_text)

# %%
num_class = 202
model_inp = Input(shape=(MAX_LENGTH,))
object_layer = Embedding(VOCAB_SIZE, 100, input_length=MAX_LENGTH)(model_inp)
a = Flatten()(object_layer)
a = Dense(30, activation="relu")(a)
model_pred = Dense(num_class, activation="softmax")(a)
output = Model(inputs=[model_inp], outputs=model_pred)

output.compile(
    optimizer="rmsprop", loss="categorical_crossentropy", metrics=["accuracy"]
)
output.summary()
# Out:
# /home/mbeleck/anaconda3/envs/tf2-cuda/lib/python3.12/site-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)      │ (None, 200)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ embedding_2 (Embedding)         │ (None, 200, 100)       │     1,000,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 20000)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 30)             │       600,030 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 202)            │         6,262 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,606,292 (6.13 MB)
#  Trainable params: 1,606,292 (6.13 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
filepath = "./output_ANN.weights.h5"
num_epochs = 10
x = ModelCheckpoint(
    filepath,
    monitor="val_acc",
    save_weights_only=True,
    verbose=1,
    save_best_only=True,
    mode="max",
)

out = output.fit(
    [X_train],
    tf.keras.utils.to_categorical(y_train),
    batch_size=64,
    validation_split=0.25,
    epochs=num_epochs,
    callbacks=[x],
)
# Out:
# Epoch 1/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 17s 77ms/step - accuracy: 0.2845 - loss: 3.2229 - val_accuracy: 0.3050 - val_loss: 2.5356
# Epoch 2/10
#   1/188 ━━━━━━━━━━━━━━━━━━━━ 28s 153ms/step - accuracy: 0.3906 - loss: 2.1222
# /home/mbeleck/anaconda3/envs/tf2-cuda/lib/python3.12/site-packages/keras/src/callbacks/model_checkpoint.py:206: UserWarning: Can save best model only with val_acc available, skipping.
#   self._save_model(epoch=epoch, batch=None, logs=logs)
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 11s 59ms/step - accuracy: 0.3112 - loss: 2.4848 - val_accuracy: 0.3050 - val_loss: 2.4770
# Epoch 3/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 10s 55ms/step - accuracy: 0.3136 - loss: 2.4731 - val_accuracy: 0.3050 - val_loss: 2.4677
# Epoch 4/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 10s 55ms/step - accuracy: 0.3064 - loss: 2.4840 - val_accuracy: 0.3050 - val_loss: 2.5296
# Epoch 5/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 10s 54ms/step - accuracy: 0.3123 - loss: 2.4601 - val_accuracy: 0.3050 - val_loss: 2.4607
# Epoch 6/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 10s 55ms/step - accuracy: 0.3135 - loss: 2.4643 - val_accuracy: 0.3050 - val_loss: 2.4676
# Epoch 7/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 10s 55ms/step - accuracy: 0.3069 - loss: 2.4589 - val_accuracy: 0.3050 - val_loss: 2.4617
# Epoch 8/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 11s 56ms/step - accuracy: 0.3036 - loss: 2.4801 - val_accuracy: 0.3050 - val_loss: 2.4601
# Epoch 9/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 10s 55ms/step - accuracy: 0.3096 - loss: 2.4590 - val_accuracy: 0.3050 - val_loss: 2.4590
# Epoch 10/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 10s 55ms/step - accuracy: 0.3121 - loss: 2.4619 - val_accuracy: 0.3050 - val_loss: 2.4631

# %%
# prediction
output_pred = output.predict(X_test)
pred_label = np.argmax(output_pred, axis=1)
accuracy = accuracy_score(y_test, pred_label)

print("Accuracy of ANN = {}".format(accuracy))
# Out:
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 805us/step
# Accuracy of ANN = 0.315

# %%
# train_acc = out.history["accuracy"]
# val_acc = out.history["val_accuracy"]

# plt.title("Training accuracy and loss")
# plt.plot(train_acc)
# plt.plot(val_acc)
# plt.xlabel("Epochs")
# plt.ylabel("")

# # print(val_acc)
# # print(train_acc)

# %% [markdown]
# # Long Short-Term Memory Model

# %%
model_inp = Input(shape=(MAX_LENGTH,))
# define embedding layer
object_layer = Embedding(VOCAB_SIZE, 100, input_length=MAX_LENGTH)(model_inp)
# add LSTM layer
a = LSTM(60)(object_layer)
# add dense layer
a = Dense(30)(a)  # default activation function is linear, we can make use of relu.

# final
model_pred = Dense(num_class, activation="softmax")(a)
output = Model(inputs=[model_inp], outputs=model_pred)
# compile
output.compile(
    optimizer="rmsprop", loss="categorical_crossentropy", metrics=["accuracy"]
)
output.summary()
# Out:
# /home/mbeleck/anaconda3/envs/tf2-cuda/lib/python3.12/site-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 200)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ embedding_1 (Embedding)         │ (None, 200, 100)       │     1,000,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm (LSTM)                     │ (None, 60)             │        38,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 30)             │         1,830 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 202)            │         6,262 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,046,732 (3.99 MB)
#  Trainable params: 1,046,732 (3.99 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
filepath = "/home/mbeleck/projects/E-commerse Product Categorization/output_LSTM.keras"

# model checkpoint
x = ModelCheckpoint(
    filepath, monitor="val_acc", verbose=1, save_best_only=True, mode="max"
)

# fitting
out = output.fit(
    X_train,
    batch_size=64,
    y=to_categorical(y_train),
    verbose=1,
    validation_split=0.25,
    shuffle=True,
    epochs=5,
    callbacks=[x],
)

# output.load_weights(
#     "/home/mbeleck/projects/E-commerse Product Categorization/output_LSTM.keras"
# )

# predicting on validation data
output_pred = output.predict(y_test)
output_pred = np.argmax(output_pred, axis=1)
# score
accuracy_score(y_test, output_pred)
# Out:
# Epoch 1/5
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 8s 32ms/step - accuracy: 0.3071 - loss: 3.0275 - val_accuracy: 0.3050 - val_loss: 2.4761
# Epoch 2/5
#   5/188 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - accuracy: 0.3076 - loss: 2.4608
# /home/mbeleck/anaconda3/envs/tf2-cuda/lib/python3.12/site-packages/keras/src/callbacks/model_checkpoint.py:206: UserWarning: Can save best model only with val_acc available, skipping.
#   self._save_model(epoch=epoch, batch=None, logs=logs)
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - accuracy: 0.3073 - loss: 2.4688 - val_accuracy: 0.3050 - val_loss: 2.4639
# Epoch 3/5
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 5s 28ms/step - accuracy: 0.3113 - loss: 2.4604 - val_accuracy: 0.3050 - val_loss: 2.4625
# Epoch 4/5
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - accuracy: 0.3131 - loss: 2.4575 - val_accuracy: 0.3050 - val_loss: 2.4636
# Epoch 5/5
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 5s 28ms/step - accuracy: 0.3036 - loss: 2.4616 - val_accuracy: 0.3050 - val_loss: 2.4644
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[27], line 25
#       9 out = output.fit(
#      10     X_train,
#      11     batch_size=64,
#    (...)
#      17     callbacks=[x],
#      18 )
#      20 # output.load_weights(
#      21 #     "/home/mbeleck/projects/E-commerse Product Categorization/output_LSTM.keras"
#      22 # )
#      23
#      24 # predicting on validation data
# ---> 25 output_pred = output.predict(y_test)
#      26 output_pred = np.argmax(output_pred, axis=1)
#      27 # score
#
# File ~/anaconda3/envs/tf2-cuda/lib/python3.12/site-packages/keras/src/utils/traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File ~/anaconda3/envs/tf2-cuda/lib/python3.12/site-packages/keras/src/models/functional.py:244, in Functional._adjust_input_rank(self, flat_inputs)
#     242             adjusted.append(ops.expand_dims(x, axis=-1))
#     243             continue
# --> 244     raise ValueError(
#     245         f"Invalid input shape for input {x}. Expected shape "
#     246         f"{ref_shape}, but input has incompatible shape {x.shape}"
#     247     )
#     248 # Add back metadata.
#     249 for i in range(len(flat_inputs)):
#
# ValueError: Exception encountered when calling Functional.call().
#
# Invalid input shape for input Tensor("functional_1_1/Cast:0", shape=(32,), dtype=float32). Expected shape (None, 200), but input has incompatible shape (32,)
#
# Arguments received by Functional.call():
#   • inputs=tf.Tensor(shape=(32,), dtype=int64)
#   • training=False
#   • mask=None

# %%
accuracy = pd.DataFrame(
    {
        "Number of epoch": out.epoch,
        "Model hist": out.history["accuracy"],
        "Model Perd": out.history["val_accuracy"],
    }
)
# line for train accuracy
g = sns.pointplot(x="Number of epoch", y="Model hist", data=dfaccuracy)
# line for test
g = sns.pointplot(x="Number of epoch", y="Model Perd", data=dfaccuracy, color="Red")

# %% [markdown]
# # Convolution

# %%
model_inp = Input(shape=(MAX_LENGTH,))
# define the layer
object_layer = Embedding(VOCAB_SIZE, 100, input_length=MAX_LENGTH)(model_inp)
# conv layer
a = Conv1D(60, 10)(object_layer)  # default activation function is linear
# add pooling layer
a = MaxPooling1D(pool_size=2)(a)
# add LSTM
a = LSTM(60)(a)
a = Dense(30)(a)
# final layer
model_pred = Dense(num_class, activation="softmax")(a)
output = Model(inputs=[model_inp], outputs=model_pred)
# compile
output.compile(optimizer="sgd", loss="categorical_crossentropy", metrics=["acc"])
output.summary()
# Out:
# /home/mbeleck/anaconda3/envs/tf2-cuda/lib/python3.12/site-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Model: "functional_8"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_11 (InputLayer)     │ (None, 200)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ embedding_9 (Embedding)         │ (None, 200, 100)       │     1,000,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d (Conv1D)                 │ (None, 191, 60)        │        60,060 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d (MaxPooling1D)    │ (None, 95, 60)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_8 (LSTM)                   │ (None, 60)             │        29,040 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_20 (Dense)                │ (None, 30)             │         1,830 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_21 (Dense)                │ (None, 202)            │         6,262 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,097,192 (4.19 MB)
#  Trainable params: 1,097,192 (4.19 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
filepath = "output_CNN.keras"
x = ModelCheckpoint(
    filepath, monitor="val_acc", verbose=1, save_best_only=True, mode="max"
)
out = output.fit(
    [X_train],
    batch_size=64,
    y=to_categorical(y_train),
    verbose=1,
    validation_split=0.25,
    shuffle=True,
    epochs=5,
    callbacks=[x],
)
output.load_weights("output_CNN.keras")
predicted = output.predict(X_test)
predicted = np.argmax(predicted, axis=1)
accuracy_score(y_test, predicted)
# Out:
# Epoch 1/5
# W0000 00:00:1728174476.280575    1439 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174476.304438    1439 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174476.314072    1439 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174476.333351    1439 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174476.342604    1439 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174476.351009    1439 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174476.360796    1439 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174476.369343    1439 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174476.376420    1439 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174476.384704    1439 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174476.393098    1439 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174476.401571    1439 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174476.410281    1439 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174476.419932    1439 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174476.427952    1439 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174476.435662    1439 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174476.442407    1439 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174476.450077    1439 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174476.457726    1439 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174476.467018    1439 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174476.478126    1439 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174476.484552    1439 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174476.492190    1439 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174476.508809    1439 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174476.516716    1439 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174476.525782    1439 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174476.636188    1439 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174476.642737    1439 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174476.647698    1439 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174476.652497    1439 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174476.657791    1439 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174476.663107    1439 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174476.668739    1439 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174476.672526    1439 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174476.679962    1439 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174476.684592    1439 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174476.688966    1439 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174476.694369    1439 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174476.699040    1439 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174476.704363    1439 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174476.710009    1439 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174476.715501    1439 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174476.724075    1439 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174476.733627    1439 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174476.741144    1439 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174476.748029    1439 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174476.754591    1439 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
#   1/188 ━━━━━━━━━━━━━━━━━━━━ 5:10 2s/step - acc: 0.0000e+00 - loss: 5.2955
# W0000 00:00:1728174477.192106    1439 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174477.253286    1439 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174477.255462    1439 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174477.256370    1439 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174477.257199    1439 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174477.258078    1439 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174477.260978    1439 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174477.261798    1439 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174477.265367    1439 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174477.266284    1439 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174477.267342    1439 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174477.268268    1439 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174477.300490    1439 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174477.301926    1439 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174477.302949    1439 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174477.313908    1439 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174477.314929    1439 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174477.318490    1439 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174477.319791    1439 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174477.321085    1439 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174477.322074    1439 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - acc: 0.2981 - loss: 5.0416
# W0000 00:00:1728174480.857210    1447 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174480.858393    1447 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174480.859555    1447 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174480.860609    1447 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174480.861844    1447 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174480.862906    1447 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174480.863914    1447 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174480.864943    1447 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174480.866024    1447 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174480.867100    1447 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174480.868285    1447 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174480.869363    1447 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174480.870486    1447 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174480.871805    1447 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174480.872785    1447 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174480.873820    1447 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174480.875001    1447 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174480.876037    1447 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174480.877048    1447 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174480.878471    1447 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174480.879470    1447 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174480.880694    1447 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174480.882024    1447 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174480.883233    1447 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174480.884416    1447 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174480.885875    1447 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174480.901174    1447 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174480.902623    1447 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174480.903687    1447 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174480.904735    1447 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174480.905782    1447 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174480.906826    1447 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174480.907928    1447 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174480.908970    1447 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174480.910427    1447 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174480.911539    1447 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174480.912704    1447 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174480.914142    1447 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174480.915230    1447 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174480.916744    1447 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174480.918148    1447 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174480.919455    1447 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174480.920764    1447 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174480.922632    1447 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174480.924272    1447 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174480.925813    1447 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174480.927517    1447 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174481.003872    1447 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174481.009651    1447 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174481.010528    1447 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174481.011362    1447 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174481.012163    1447 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174481.012953    1447 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174481.013765    1447 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174481.014554    1447 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174481.015355    1447 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174481.016240    1447 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174481.017146    1447 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174481.018080    1447 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174481.019033    1447 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174481.020153    1447 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174481.021389    1447 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174481.022392    1447 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174481.023322    1447 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174481.024149    1447 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174481.025031    1447 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174481.025902    1447 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174481.210476    1450 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174481.211501    1450 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174481.212526    1450 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174481.213435    1450 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174481.214383    1450 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174481.215300    1450 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174481.216228    1450 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174481.217212    1450 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174481.218244    1450 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174481.219320    1450 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174481.220283    1450 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174481.221384    1450 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174481.222436    1450 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174481.223761    1450 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174481.224874    1450 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174481.226159    1450 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174481.227179    1450 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174481.228157    1450 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174481.229354    1450 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174481.236307    1450 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174481.237454    1450 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174481.238696    1450 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174481.240344    1450 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# Epoch 1: val_acc improved from -inf to 0.30500, saving model to output_CNN.keras
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - acc: 0.2982 - loss: 5.0390 - val_acc: 0.3050 - val_loss: 3.2770
# Epoch 2/5
#   4/188 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - acc: 0.2406 - loss: 3.4958
# W0000 00:00:1728174481.926602    1447 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174481.927544    1447 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174481.928436    1447 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174481.929295    1447 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174481.930131    1447 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174481.931050    1447 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174481.931936    1447 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174481.932785    1447 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174481.933706    1447 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174481.934629    1447 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174481.935501    1447 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174481.936496    1447 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174481.937361    1447 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174481.938348    1447 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174481.939225    1447 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174481.940351    1447 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174481.941379    1447 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174481.942352    1447 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174481.943280    1447 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174481.944254    1447 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174481.945187    1447 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174481.946169    1447 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728174481.947324    1447 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - acc: 0.3074 - loss: 3.0282
# Epoch 2: val_acc did not improve from 0.30500
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - acc: 0.3074 - loss: 3.0273 - val_acc: 0.3050 - val_loss: 2.6492
# Epoch 3/5
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - acc: 0.3076 - loss: 2.5930
# Epoch 3: val_acc did not improve from 0.30500
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - acc: 0.3076 - loss: 2.5929 - val_acc: 0.3050 - val_loss: 2.5311
# Epoch 4/5
# 186/188 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - acc: 0.3050 - loss: 2.5386
# Epoch 4: val_acc did not improve from 0.30500
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 4s 20ms/step - acc: 0.3051 - loss: 2.5381 - val_acc: 0.3050 - val_loss: 2.4965
# Epoch 5/5
# 186/188 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - acc: 0.3086 - loss: 2.4773
# Epoch 5: val_acc did not improve from 0.30500
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 4s 20ms/step - acc: 0.3086 - loss: 2.4775 - val_acc: 0.3050 - val_loss: 2.4841
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step
# 0.315
